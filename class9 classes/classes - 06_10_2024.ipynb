# %%
name = 'Qasim'

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
dictionary = {'f_name':'Qasim', 'l_name':'Hassan'}

# %%
print(type(dictionary))
# Out:
# <class 'dict'>

# %% [markdown]
# - Everything in Python is actually belongng to any Class
# - Every class canbe initialized as Object

# %%
dictionary.keys()
# Out:
# dict_keys(['f_name', 'l_name'])

# %% [markdown]
# - Every class have some *MTHEODS*
# - Every object initialized have those *METHODS* that are in class.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
class smit(): # class
    def __init__(self, id_card, f_name, l_name, typee): # constructor
        self.id_card = id_card # attrbutes
        self.first_name = f_name
        self.last_name = l_name
        self.typee = typee
   
    def details(self): # methods
        print(f"{self.first_name} {self.last_name} is a {self.typee} member with id {self.id_card}")

# %%
hamza = smit('py-12345', 'Hamza', 'Aslam', 'Student') # object

# %%
hamza.id_card
# Out:
# 'py-12345'

# %%
hamza.first_name
# Out:
# 'Hamza'

# %%
hamza.details()
# Out:
# Hamza Aslam is a Student member with id py-12345

# %%
amir = smit('saff-12345', 'Aamir', 'paii', 'Staff')

# %% [markdown]
# f"{amir.first_name} {amir.last_name} is a {amir.typee} member with id {amir.id_card}"

# %%
amir.details()
# Out:
# Aamir paii is a Staff member with id saff-12345

# %% [markdown]
# ## TASK
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Working with Banking Case Study:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class BankAccount:
    def __init__(self,accountnumber,accountname,balance=0):
        self.accountnumber = accountnumber
        self.accountname = accountname
        self.balance = balance 
        
    def deposit(self,amount):
        self.balance += amount
        print("Your new balance is ",self.balance)
        
    def withdraw(self,amount):
        if amount < 0 :
            print("Amount must be in positive")
        elif amount > self.balance:
            print("Insufficent funds")
        else:
            self.balance -= amount
            print("Your new balance is ",self.balance)
            
    def transfer(self,sending,receipent_account,amount):
        if amount>self.balance:
            print("Insufficient funds")
        else:
            sending.withdraw(amount)
            receipent_account.deposit(amount)
            print("Ammount Succesfully transfered")

# %%
obj1 = BankAccount(123457,"Danish",50000)

# %%
obj1.deposit(5000)
# Out:
# Your new balance is  55000

# %%
obj1.withdraw(6000)
# Out:
# Your new balance is  49000

# %%
obj2 = BankAccount(123456789,"Mehdi",50000)

# %%
obj1.transfer(obj1,obj2,2000)
# Out:
# Your new balance is  47000
# Your new balance is  52000
# Ammount Succesfully transfered

# %% [markdown]
# #### Class Variables:
#     - Static Variable
#     - Dynamic Variable

# %%
class smit(): # class
    title = 'Saylani Mass IT Training'
    id_card = 0 # attrbutes
    
    def __init__(self, f_name, l_name, typee): # constructor
        self.first_name = f_name
        self.last_name = l_name
        self.typee = typee
        smit.id_card +=1
   
    def details(self): # methods
        print(f"{self.first_name} {self.last_name} is a {self.typee} member with id {self.id_card}")

# %%
hamza = smit('Hamza', 'Aslam', 'Student') # object1 --> 1

# %%
hamza.id_card
# Out:
# 2

# %%
amir = smit('Aamir', 'paii', 'Staff') # object2 --> 2

# %%
amir.id_card
# Out:
# 2

# %% [markdown]
# #### TASK: use above cat/dog example and Intro some static & dynamic class variables

# %%
class Sam_The_Dog:
    breed = "Golden Retriever"
    puppies = 0
    def __init__(self,name,age):
        self.name = name
        self.age = age
        Sam_The_Dog.puppies += 1

# %%
Kate = Sam_The_Dog("Kate",2)

# %%
Mash = Sam_The_Dog("Mash",5)

# %%
Sam_The_Dog.breed
# Out:
# 'Golden Retriever'

# %%
Sam_The_Dog.puppies
# Out:
# 2

# %% [markdown]
# - OOP Stands for Object Oriented Programing
# - OOP have four pillar
#     - Inheritance ( getting attributes/methods from parent class)
#     - polymorphism (Same instance behaving differently)
#     - Abstraction (Structure of the code without implementation)
#     - Encapsulation ( hiding of attributes/methods)
